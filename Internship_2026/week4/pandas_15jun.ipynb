# %%
#pandas

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1D data structures in pandas

# %%
# Pandas series

# %%
#Creating Pandas series

# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s = pd.Series([13,15,11])

# %%
s
# Out:
# 0    13
# 1    15
# 2    11
# dtype: int64

# %%
s = pd.Series([10,20,30], index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# with custom index

# %%
s = pd.Series([name, age, marks], index =['shreya','18','90'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 s = pd.Series([name, age, marks], index =['shreya','18','90'])
#
# NameError: name 'name' is not defined

# %%
#from Dictionary

# %%
data = {'name':"shreya",'Age':18,'marks':90}

# %%
s = pd.Series(data)

# %%
s
# Out:
# name     shreya
# Age          18
# marks        90
# dtype: object

# %%
data = {'name':"shruti",'Age':16,'Marks':84}

# %%
s = pd.Series(data)

# %%
s
# Out:
# name     shruti
# Age          16
# Marks        84
# dtype: object

# %%
#From a single value

# %%
s = pd.Series(5, index=[0,1,2,3])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
s = pd.Series(3, index=[0,1,2,3,4,5])

# %%
s
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# 5    3
# dtype: int64

# %%
s = pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
# Data manipulation

# %%
s = pd.Series([1,2,3])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
print(s * 3)
# Out:
# 0    3
# 1    6
# 2    9
# dtype: int64

# %%
# Handling Missing values

# %%
s = pd.Series([1,None,3])

# %%
s
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    1.0
# 2    3.0
# dtype: float64

# %%
s.fillna(0)
# Out:
# 0    1.0
# 1    0.0
# 2    3.0
# dtype: float64

# %%
# Indexing

# %%
s = pd.Series([30,20,10], index=['a','b','c'])

# %%
s
# Out:
# a    30
# b    20
# c    10
# dtype: int64

# %%
s['a']
# Out:
# np.int64(30)

# %%
s['c']
# Out:
# np.int64(10)

# %%
s['b']
# Out:
# np.int64(20)

# %%
# array

# %%
import numpy as np

# %%
a = np.array([2, 44.5, True, 'aryan'])

# %%
a
# Out:
# array(['2', '44.5', 'True', 'aryan'], dtype='<U32')
