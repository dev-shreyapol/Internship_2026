# %% [raw]
# # string function

# %%
name = "Nitish"

# %%
name.lower()
# Out:
# 'nitish'

# %%
name
# Out:
# 'Nitish'

# %%
name = name.lower()

# %%
name
# Out:
# 'nitish'

# %%
name.upper()
# Out:
# 'NITISH'

# %%
name.title()
# Out:
# 'Nitish'

# %%
name = "swapcase"

# %%
'nITISH'
# Out:
# 'nITISH'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# True

# %%
name.istitle()
# Out:
# False

# %%
name1 = "ok"
name2 = "123"

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name3.isalnum()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
name = " pune "

# %%
print(name)
# Out:
#  pune

# %%
name.startswith("P")
# Out:
# False

# %%
name.startswith(" P")
# Out:
# False

# %%
name.endswith("e")
# Out:
# False

# %% [markdown]
# name.lstrip()

# %%
name.lstrip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 name.lstrip()
#
# NameError: name 'name' is not defined

# %%
'pune '
# Out:
# 'pune '

# %% [markdown]
# ## operators

# %%
# arithmetic

# %%
a = 5
b = 17

# %%
a + b
# Out:
# 22

# %%
a - b
# Out:
# -12

# %%
b / a
# Out:
# 3.4

# %%
a * b
# Out:
# 85

# %%
a ** b #raise to
# Out:
# 762939453125

# %%
b // a #floor div
# Out:
# 3

# %%
# assignment operator

# %%
z = 5

# %%
z
# Out:
# 5

# %%
z = z+3
z
# Out:
# 8

# %%
z  += 3
z
# Out:
# 11

# %%
z -= 3

# %%
z
# Out:
# 8

# %%
z *= 3

# %%
z
# Out:
# 24

# %%
# comparison

# %%
a
# Out:
# 5

# %%
b
# Out:
# 17

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# logical operator

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
# identity operator -> is, is not

# %%
a = 5 
b = 5

# %%
id(a), id(b)
# Out:
# (140703223358504, 140703223358504)

# %%
a is b
# Out:
# True

# %%
a = [3, 4]
b = [3, 4]

# %%
id(a), id(b)
# Out:
# (2399051615744, 2399051622528)

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)

# %%
[3,4,10]
# Out:
# [3, 4, 10]

# %%
z
# Out:
# [3, 4, 10]

# %%
# membership selection opertator -> in

# %%
l = [4, 6, 19, 10]

# %%
6 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %%
2 not in l
# Out:
# True

# %%
## precedence and association

# %%
# BODMAS

# %%
5  + 2 - 10
# Out:
# -3

# %%
(4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3 #right association
# Out:
# 256

# %%
2 ** 3 // 2
# Out:
# 4

# %%
# print function

# %%
name = "Shreya"
marks = 76.57

# %%
# my name is Shreya and marks are 76.57
